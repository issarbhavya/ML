# %% [markdown]
# <a href="https://colab.research.google.com/github/issarbhavya/ML/blob/main/02_neural_network_binary__classification_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_circles
# Make 1000 examples
n_samples = 1000

# Create circles
X, y = make_circles(n_samples, 
                    noise=0.03, 
                    random_state=42)

# X : ndarray of shape (n_samples, 2)
# The generated samples.

# y : ndarray of shape (n_samples,)
# The integer labels (0 or 1) for class membership of each sample.

# %%
import pandas as pd
circles = pd.DataFrame({"X0":X[:, 0], "X1":X[:, 1], "label":y})
circles
# Out:
#            X0        X1  label
# 0    0.754246  0.231481      1
# 1   -0.756159  0.153259      1
# 2   -0.815392  0.173282      1
# 3   -0.393731  0.692883      1
# 4    0.442208 -0.896723      0
# ..        ...       ...    ...
# 995  0.244054  0.944125      0
# 996 -0.978655 -0.272373      0
# 997 -0.136900 -0.810012      1
# 998  0.670362 -0.767502      0
# 999  0.281057  0.963824      0
#
# [1000 rows x 3 columns]

# %%
# Visualize with a plot
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.RdYlBu)

# %%
import tensorflow as tf

# %%
tf.random.set_seed(42)
#create
model_1=tf.keras.Sequential([
    tf.keras.layers.Dense(1), ## takes input of one numpy array of size 2
    tf.keras.layers.Dense(10)
])

#compile
model_1.compile(loss=tf.keras.losses.BinaryCrossentropy(), ## binary since we are working with 2 clases (0 & 1)
                optimizer=tf.keras.optimizers.SGD(),
                metrics=["accuracy"]) 

#fir
model_1.fit(X,y,epochs=5, verbose=0)

# %%
model_1.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7641 - accuracy: 0.0730
# [0.7641103863716125, 0.0729999989271164]

# %%
model_1.fit(X, y, epochs=200, verbose=0)
model_1.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.0000e+00
# [0.6931548714637756, 0.0]

# %%
tf.random.set_seed(42)

model_3=tf.keras.Sequential([
    tf.keras.layers.Dense(1), ## input layer


    tf.keras.layers.Dense(100), # add 100 dense neurons
    tf.keras.layers.Dense(10), # add another layer with 10 neurons
    tf.keras.layers.Dense(1)
])

model_3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=["accuracy"]) # accuracy says out of the given data how many did we get right

model_3.fit(X, y, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 2s 5ms/step - loss: 1.6687 - accuracy: 0.5000
# Epoch 2/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6992 - accuracy: 0.4830
# Epoch 3/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6936 - accuracy: 0.4860
# Epoch 4/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6945 - accuracy: 0.4760
# Epoch 5/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6944 - accuracy: 0.4730
# Epoch 6/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6947 - accuracy: 0.4770
# Epoch 7/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6950 - accuracy: 0.5120
# Epoch 8/100
# 32/32 [==============================] - 0s 5ms/step - loss: 0.6949 - accuracy: 0.4590
# Epoch 9/100
# 32/32 [==============================] - 0s 6ms/step - loss: 0.6945 - accuracy: 0.4820
# Epoch 10/100
# ...

# %%
model_3.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.5000
# [0.6939190030097961, 0.5]

# %%
model_3.predict(X)
# Out:
# 32/32 [==============================] - 0s 2ms/step
# array([[0.51946896],
#        [0.51977515],
#        [0.5197848 ],
#        [0.5196489 ],
#        [0.519645  ],
#        [0.5196675 ],
#        [0.51956266],
#        [0.5194741 ],
#        [0.51975524],
#        [0.5195618 ],
#        [0.5198234 ],
#        [0.5194433 ],
#        [0.51958036],
#        [0.51953024],
#        [0.51958233],
#        [0.51968116],
#        [0.51986116],
#        [0.5197006 ],
#        [0.51981336],
#        [0.51984376],
#        [0.519472  ],
#        [0.5196659 ],
#        [0.51974654],
#        [0.5194671 ],
#        [0.51977456],
#        [0.51980615],
#        [0.5194855 ],
#        [0.51949376],
#        [0.5196695 ],
#        [0.51955867],
#        [0.5197952 ],
#        [0.51958495],
#        [0.5195603 ],
#        [0.51944166],
#        [0.5197673 ],
#        [0.5197274 ],
#        [0.51969576],
#        [0.51948065],
#        [0.5196648 ],
#        [0.51942927],
#        [0.51983774],
# ...

# %%
X[:,0],X[:,1]
# Out:
# (array([ 7.54246251e-01, -7.56158882e-01, -8.15391934e-01, -3.93730729e-01,
#          4.42207645e-01, -4.79646368e-01, -1.36483595e-02,  7.71513274e-01,
#         -1.69322340e-01, -1.21485796e-01, -6.42490416e-01,  5.69466604e-01,
#         -1.17735911e-01,  7.34100038e-01,  6.00776333e-01,  1.90225707e-01,
#         -9.36951846e-01,  1.07061696e-01, -8.18913619e-01, -6.42100130e-01,
#          6.26827199e-01, -5.62291360e-01, -2.12666579e-02,  7.39770578e-01,
#         -9.09048393e-01, -9.36994111e-01,  2.86615780e-01,  8.26260717e-01,
#          2.53433397e-01,  6.57946255e-01, -3.14834779e-01, -2.23989601e-01,
#          8.44389246e-03,  1.00503887e+00, -8.95158198e-02, -7.88574473e-01,
#         -5.68205362e-01,  4.47646782e-01,  2.63260719e-01,  7.45020435e-01,
#         -5.97118971e-01,  3.61928379e-01, -7.14242507e-01,  8.33839377e-01,
#         -8.33981856e-01, -9.10860642e-01,  4.87625557e-01,  2.30736878e-01,
# ...

# %%
x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1

x_min,x_max,y_min,y_max
# Out:
# (-1.1595024599098636,
#  1.1337117525463374,
#  -1.1677683182718437,
#  1.1360036756154805)

# %%
import numpy as np

# %%
def plot_decision_boundary(model, X, y):

   # Define the axis boundaries of the plot and create a meshgrid
   x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
   y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1

    # The output of np.meshgrid() can be useful for creating grids of points for plotting
    # or for evaluating functions over a grid of points.
   xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))

   # what linspace do is : Return evenly spaced numbers over a specified interval.
   # np.linspace(2.0, 3.0, num=5)
   # array([2.  , 2.25, 2.5 , 2.75, 3.  ])
   
   ##### Create X values (we're going to predict on all of these)
   x_in = np.c_[xx.ravel(), yy.ravel()]


   # what np.c_ do is : 
   # np.c_[np.array([1,2,3]), np.array([4,5,6])]
   # array([[1, 4],
   #      [2, 5],
   #      [3, 6]])
  
   # what ravel do is :
   # x = np.array([[1, 2, 3], [4, 5, 6]])
   # np.ravel(x)
   # array([1, 2, 3, 4, 5, 6])

   ##### Make predictions using the trained model
   y_pred = model.predict(x_in)  

  # Check for multi-class
   if len(y_pred[0])> 1: 
     # checks the final dimension of the model's output shape, if this is > (greater than) 1, it's multi-class 
     print("doing multiclass classification...")
     # We have to reshape our predictions to get them ready for plotting
     y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)

     ## argmax : The function returns the indices of the maximum values along a specified axis in an array.

   else:
     print("doing binary classifcation...")
     y_pred = np.round(y_pred).reshape(xx.shape) 
     # first roundoff is done using round function
     # then, y_pred is brought to the same shape as of xx

   # Plot decision boundary
     plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7) # Contour: imag. line connecting points of eql val
     #contour and contourf draw contour lines and filled contours, respectively.

     plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu) # plots the 2 circles

    #  plt.xlim(xx.min(), xx.max()) # Get or set the x limits of the current axes.(here set)
    #  plt.ylim(yy.min(), yy.max())





## the below commented section is to understand working 

#    print("value of xx and yy is : ",xx) ## for yy everything will be similar
#    print("ravel values",xx.ravel())
# plot_decision_boundary(model_3,X,y)

# %%
# Check out the predictions our model is making
plot_decision_boundary(model_3, X, y)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...

# %%
tf.random.set_seed(42)

# Create the model
model_4 = tf.keras.Sequential([
  tf.keras.layers.Dense(1, activation=tf.keras.activations.linear), # 1 hidden layer with linear activation
  tf.keras.layers.Dense(1) # output layer
])

# Compile the model
model_4.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), # note: "lr" used to be what was used, now "learning_rate" is favoured
                metrics=["accuracy"])

# Fit the model
history = model_4.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 6.6567 - accuracy: 0.4880
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.6527 - accuracy: 0.4870
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.6401 - accuracy: 0.4860
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.6063 - accuracy: 0.4890
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.5793 - accuracy: 0.4880
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.5776 - accuracy: 0.4880
# Epoch 7/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.5510 - accuracy: 0.4870
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.5257 - accuracy: 0.4880
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 6.5215 - accuracy: 0.4880
# Epoch 10/100
# ...

# %%
plot_decision_boundary(model_4, X, y)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...

# %% [markdown]
# it looks like our model is sill predicting straight lines, the yellow part suggests that in that it can be anything, red or blue

# %%
tf.random.set_seed(42)

# Create a model with a non-linear activation
model_5 = tf.keras.Sequential([
  tf.keras.layers.Dense(1, activation=tf.keras.activations.relu), # can also do activation='relu'
  tf.keras.layers.Dense(1) # output layer 
])

# Compile the model
model_5.compile(loss=tf.keras.losses.binary_crossentropy,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# Fit the model
history = model_5.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 7/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 10/100
# ...

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model
model_6 = tf.keras.Sequential([
  tf.keras.layers.Dense(4, activation=tf.keras.activations.relu), # hidden layer 1, 4 neurons, ReLU activation
  tf.keras.layers.Dense(4, activation=tf.keras.activations.relu), # hidden layer 2, 4 neurons, ReLU activation
  tf.keras.layers.Dense(1) # ouput layer
])

# Compile the model
model_6.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(lr=0.001), # Adam's default learning rate is 0.001
                metrics=['accuracy'])

# Fit the model
history = model_6.fit(X, y, epochs=100)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 32/32 [==============================] - 1s 4ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 2/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 4/100
# 32/32 [==============================] - 0s 4ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 7/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 9/100
# ...

# %%
model_6.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# [7.712474346160889, 0.5]

# %%
plot_decision_boundary(model_6, X, y)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...

# %%
# Split data into train and test sets
X_train, y_train = X[:800], y[:800] # 80% of the data for the training set
X_test, y_test = X[800:], y[800:] # 20% of the data for the test set

# Check the shapes of the data
X_train.shape, X_test.shape
# Out:
# ((800, 2), (200, 2))

# %%
tf.random.set_seed(42)

# Create a model
model_7 = tf.keras.Sequential([
  tf.keras.layers.Dense(4, activation=tf.keras.activations.relu), # hidden layer 1, ReLU activation
  tf.keras.layers.Dense(4, activation=tf.keras.activations.relu), # hidden layer 2, ReLU activation

  tf.keras.layers.Dense(4, activation=tf.keras.activations.relu), ### added by me by myself, coz earlier was not coming correct 

  tf.keras.layers.Dense(1, activation=tf.keras.activations.sigmoid) # ouput layer, sigmoid activation
])

# Compile the model
model_7.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

# Fit the model
history_7 = model_7.fit(X_train, y_train, epochs=100, verbose=0)

# %%
model_7.evaluate(X_test, y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1819 - accuracy: 0.9650
# [0.181910902261734, 0.9649999737739563]

# %%
plot_decision_boundary(model_7, X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...

# %%
pd.DataFrame(history_7.history).plot()
plt.title("Model_7 training curves")
# Out:
# Text(0.5, 1.0, 'Model_7 training curves')

# %%
len(X)
# Out:
# 1000

# %%
# Set random seed
tf.random.set_seed(42)

# Create the model (same as model_7)
model_8 = tf.keras.Sequential([
  tf.keras.layers.Dense(4, activation="relu"), # hidden layer 1, using "relu" for activation (same as tf.keras.activations.relu)
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),

  tf.keras.layers.Dense(1, activation="sigmoid") # output layer, using 'sigmoid' for the output
])

# Compile the model
model_8.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(lr=0.01), # increase learning rate from 0.001 to 0.01 for faster learning
                metrics=['accuracy'])

# Fit the model
history_8 = model_8.fit(X_train, y_train, epochs=120)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/120
# 25/25 [==============================] - 2s 4ms/step - loss: 0.6965 - accuracy: 0.4963
# Epoch 2/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6955 - accuracy: 0.4762
# Epoch 3/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6948 - accuracy: 0.4863
# Epoch 4/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6942 - accuracy: 0.4775
# Epoch 5/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6938 - accuracy: 0.4800
# Epoch 6/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6936 - accuracy: 0.4775
# Epoch 7/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6930 - accuracy: 0.4762
# Epoch 8/120
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6928 - accuracy: 0.4812
# Epoch 9/120
# ...

# %% [markdown]
# visualise, visualise visualise may not match to the code from anwer booklet, but on visualisation we can see the given code dosen't perform good, but increasing the epochs result in .99 accuracy
#
# ---

# %%
model_8.evaluate(X_test, y_test)
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9900
# [0.06632216274738312, 0.9900000095367432]

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model_8, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model_8, X=X_test, y=y_test)
plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...
# 313/313 [==============================] - 0s 1ms/step
# doing binary classifcation...

# %%
# You can access the information in the history variable using the .history attribute
pd.DataFrame(history_8.history)
# Out:
#          loss  accuracy
# 0    0.696522   0.49625
# 1    0.695504   0.47625
# 2    0.694753   0.48625
# 3    0.694182   0.47750
# 4    0.693817   0.48000
# ..        ...       ...
# 115  0.073662   0.99625
# 116  0.070779   0.99625
# 117  0.068700   0.99500
# 118  0.066146   0.99750
# 119  0.063933   0.99750
#
# [120 rows x 2 columns]

# %%
# Plot the loss curves
pd.DataFrame(history_8.history).plot()
plt.title("Model_8 training curves")
# Out:
# Text(0.5, 1.0, 'Model_8 training curves')

# %% [markdown]
# ---
#
#
# Finding the best learning rate
#
# ---

# %% [markdown]
# ## More classification evaluation methods

# %% [markdown]
# * Accuracy : Out of 100 predictions, how many does your model get correct? E.g. 95% accuracy means it gets 95/100 predictions correct.
#
#
# * Precision :	Proportion of true positives over total number of samples. Higher precision leads to less false positives (model predicts 1 when it should've been 0).
#
# * Recall :	Proportion of true positives over total number of true positives and false negatives (model predicts 0 when it should've been 1). Higher recall leads to less false negatives.
#
#
# unfortunetely, you can't have both recall nd precision high, if you increase one then the other will reduce automaticlly
#
#
# * F1-score	Combines precision and recall into one metric. 1 is best, 0 is worst.
#
# * Confusion matrix	Compares the predicted values with the true values in a tabular way, if 100% correct, all values in the matrix will be top left to bottom right (diagnol line).

# %%
y_preds = model_8.predict(X_test)

y_test[:10], y_preds[:10]
# Out:
# 7/7 [==============================] - 0s 3ms/step
# (array([1, 1, 1, 1, 0, 0, 1, 0, 1, 0]),
#  array([[0.89639664],
#         [0.9550223 ],
#         [0.9197805 ],
#         [0.964459  ],
#         [0.1399067 ],
#         [0.01915394],
#         [0.8078627 ],
#         [0.015054  ],
#         [0.9555464 ],
#         [0.12915137]], dtype=float32))

# %% [markdown]
# It looks like we need to get our predictions into the binary format (0 or 1).
#
# In their current format (9.8526537e-01), they're in a form called prediction probabilities.
#
# we can convert the prediction probabilities using to their binary form using tf.round()

# %%
# Convert prediction probabilities to binary format and view the first 10
tf.round(y_preds)[:10]
# Out:
# <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [0.],
#        [0.],
#        [1.],
#        [0.],
#        [1.],
#        [0.]], dtype=float32)>

# %%
# Create a confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(y_test, tf.round(y_preds))
# Out:
# array([[100,   1],
#        [  1,  98]])

# %% [markdown]
# That looks much better. It seems our model has made almost perfect predictions on the test set except for two false
